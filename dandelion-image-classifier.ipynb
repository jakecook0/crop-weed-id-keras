# %%
import numpy as np
import pandas as pd
import os
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.preprocessing import image

data_dir = pathlib.Path(os.path.join('/kaggle/input/dandelionimages','Images'))

batch_size = 16
img_height = 180
img_width = 180

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=212,
  image_size=(img_height, img_width),
  batch_size=batch_size)


val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=212,
  image_size=(img_height, img_width),
  batch_size=batch_size)

class_names = train_ds.class_names

AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

num_classes = 2

model = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255,input_shape=(img_height, img_width, 3)),
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
    tf.keras.layers.Conv2D(16, 3, padding='same'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Dense(4),
    tf.keras.layers.Dense(num_classes)
    
])

model.summary()

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

epochs=60
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

model.save('Model1/my_model',overwrite=True)
# Out:
# Found 1262 files belonging to 2 classes.
# Using 1010 files for training.
# Found 1262 files belonging to 2 classes.
# Using 252 files for validation.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 180, 180, 3)       0
# _________________________________________________________________
# random_flip (RandomFlip)     (None, 180, 180, 3)       0
# _________________________________________________________________
# random_rotation (RandomRotat (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 129600)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 129600)            0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 518404
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 10
# =================================================================
# Total params: 518,862
# Trainable params: 518,862
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 64/64 [==============================] - 172s 670ms/step - loss: 2.9248 - accuracy: 0.5339 - val_loss: 0.7466 - val_accuracy: 0.6190
# Epoch 2/60
# 64/64 [==============================] - 11s 176ms/step - loss: 0.6141 - accuracy: 0.6549 - val_loss: 0.7061 - val_accuracy: 0.6389
# Epoch 3/60
# 64/64 [==============================] - 11s 168ms/step - loss: 0.6206 - accuracy: 0.6596 - val_loss: 0.6771 - val_accuracy: 0.6746
# Epoch 4/60
# 64/64 [==============================] - 11s 170ms/step - loss: 0.6572 - accuracy: 0.6610 - val_loss: 0.6468 - val_accuracy: 0.6825
# Epoch 5/60
# 64/64 [==============================] - 11s 175ms/step - loss: 0.6295 - accuracy: 0.6578 - val_loss: 0.6567 - val_accuracy: 0.6825
# Epoch 6/60
# 64/64 [==============================] - 11s 170ms/step - loss: 0.6927 - accuracy: 0.6433 - val_loss: 0.7738 - val_accuracy: 0.6349
# Epoch 7/60
# 64/64 [==============================] - 11s 171ms/step - loss: 0.6286 - accuracy: 0.6523 - val_loss: 0.7234 - val_accuracy: 0.6230
# Epoch 8/60
# 64/64 [==============================] - 11s 172ms/step - loss: 0.6443 - accuracy: 0.6689 - val_loss: 0.7157 - val_accuracy: 0.6429
# Epoch 9/60
# 64/64 [==============================] - 11s 168ms/step - loss: 0.6794 - accuracy: 0.6173 - val_loss: 0.8071 - val_accuracy: 0.6310
# Epoch 10/60
# 64/64 [==============================] - 11s 170ms/step - loss: 0.6042 - accuracy: 0.6930 - val_loss: 0.5718 - val_accuracy: 0.7143
# Epoch 11/60
# 64/64 [==============================] - 11s 174ms/step - loss: 0.5768 - accuracy: 0.6898 - val_loss: 0.6740 - val_accuracy: 0.6627
# Epoch 12/60
# 64/64 [==============================] - 11s 167ms/step - loss: 0.6069 - accuracy: 0.6667 - val_loss: 0.5492 - val_accuracy: 0.7302
# Epoch 13/60
# 64/64 [==============================] - 11s 170ms/step - loss: 0.5810 - accuracy: 0.6974 - val_loss: 0.5783 - val_accuracy: 0.6865
# Epoch 14/60
# 64/64 [==============================] - 11s 172ms/step - loss: 0.5978 - accuracy: 0.6820 - val_loss: 0.5644 - val_accuracy: 0.6944
# Epoch 15/60
# 64/64 [==============================] - 11s 169ms/step - loss: 0.5606 - accuracy: 0.7011 - val_loss: 0.6571 - val_accuracy: 0.6468
# Epoch 16/60
# 64/64 [==============================] - 11s 167ms/step - loss: 0.5595 - accuracy: 0.7101 - val_loss: 0.5424 - val_accuracy: 0.7183
# Epoch 17/60
# 64/64 [==============================] - 12s 193ms/step - loss: 0.5677 - accuracy: 0.6973 - val_loss: 0.5571 - val_accuracy: 0.7063
# Epoch 18/60
# 64/64 [==============================] - 14s 222ms/step - loss: 0.5479 - accuracy: 0.7160 - val_loss: 0.5339 - val_accuracy: 0.7500
# Epoch 19/60
# 64/64 [==============================] - 11s 170ms/step - loss: 0.5485 - accuracy: 0.6891 - val_loss: 0.6495 - val_accuracy: 0.6587
# Epoch 20/60
# 64/64 [==============================] - 11s 174ms/step - loss: 0.5890 - accuracy: 0.7035 - val_loss: 0.5575 - val_accuracy: 0.7302
# Epoch 21/60
# 64/64 [==============================] - 11s 174ms/step - loss: 0.5709 - accuracy: 0.6872 - val_loss: 0.5717 - val_accuracy: 0.6905
# Epoch 22/60
# 64/64 [==============================] - 11s 172ms/step - loss: 0.5726 - accuracy: 0.6992 - val_loss: 0.5885 - val_accuracy: 0.6944
# Epoch 23/60
# 64/64 [==============================] - 11s 178ms/step - loss: 0.5547 - accuracy: 0.7049 - val_loss: 0.5976 - val_accuracy: 0.6905
# Epoch 24/60
# 64/64 [==============================] - 11s 168ms/step - loss: 0.5434 - accuracy: 0.7429 - val_loss: 0.6071 - val_accuracy: 0.6905
# Epoch 25/60
# 64/64 [==============================] - 11s 171ms/step - loss: 0.5823 - accuracy: 0.6869 - val_loss: 0.6217 - val_accuracy: 0.6587
# Epoch 26/60
# 64/64 [==============================] - 11s 174ms/step - loss: 0.6020 - accuracy: 0.6841 - val_loss: 0.5904 - val_accuracy: 0.6944
# Epoch 27/60
# 64/64 [==============================] - 11s 167ms/step - loss: 0.5758 - accuracy: 0.6973 - val_loss: 0.5467 - val_accuracy: 0.7222
# Epoch 28/60
# 64/64 [==============================] - 11s 173ms/step - loss: 0.5431 - accuracy: 0.7231 - val_loss: 0.7113 - val_accuracy: 0.6389
# Epoch 29/60
# 64/64 [==============================] - 11s 175ms/step - loss: 0.5594 - accuracy: 0.7131 - val_loss: 0.5537 - val_accuracy: 0.7381
# Epoch 30/60
# 64/64 [==============================] - 11s 167ms/step - loss: 0.5488 - accuracy: 0.6952 - val_loss: 0.5242 - val_accuracy: 0.7262
# Epoch 31/60
# 64/64 [==============================] - 11s 172ms/step - loss: 0.5548 - accuracy: 0.7005 - val_loss: 0.6112 - val_accuracy: 0.6905
# Epoch 32/60
# 64/64 [==============================] - 11s 173ms/step - loss: 0.5278 - accuracy: 0.7366 - val_loss: 0.5365 - val_accuracy: 0.7063
# Epoch 33/60
# 64/64 [==============================] - 11s 167ms/step - loss: 0.5890 - accuracy: 0.6936 - val_loss: 0.5111 - val_accuracy: 0.7222
# Epoch 34/60
# 64/64 [==============================] - 11s 173ms/step - loss: 0.5462 - accuracy: 0.7156 - val_loss: 0.6023 - val_accuracy: 0.6905
# Epoch 35/60
# 64/64 [==============================] - 11s 174ms/step - loss: 0.5662 - accuracy: 0.7387 - val_loss: 0.6036 - val_accuracy: 0.6825
# Epoch 36/60
# 64/64 [==============================] - 11s 167ms/step - loss: 0.5724 - accuracy: 0.6938 - val_loss: 0.6156 - val_accuracy: 0.6667
# Epoch 37/60
# 64/64 [==============================] - 11s 173ms/step - loss: 0.5267 - accuracy: 0.7343 - val_loss: 0.5393 - val_accuracy: 0.7024
# Epoch 38/60
# 64/64 [==============================] - 11s 172ms/step - loss: 0.5463 - accuracy: 0.7227 - val_loss: 0.5450 - val_accuracy: 0.7063
# Epoch 39/60
# 64/64 [==============================] - 11s 168ms/step - loss: 0.5510 - accuracy: 0.7159 - val_loss: 0.5555 - val_accuracy: 0.7024
# Epoch 40/60
# 64/64 [==============================] - 11s 178ms/step - loss: 0.5475 - accuracy: 0.7073 - val_loss: 0.6005 - val_accuracy: 0.6786
# Epoch 41/60
# 64/64 [==============================] - 11s 167ms/step - loss: 0.5518 - accuracy: 0.7444 - val_loss: 0.5614 - val_accuracy: 0.7143
# Epoch 42/60
# 64/64 [==============================] - 11s 167ms/step - loss: 0.5424 - accuracy: 0.7490 - val_loss: 0.6101 - val_accuracy: 0.6746
# Epoch 43/60
# 64/64 [==============================] - 11s 179ms/step - loss: 0.5741 - accuracy: 0.6777 - val_loss: 0.5841 - val_accuracy: 0.6984
# Epoch 44/60
# 64/64 [==============================] - 11s 167ms/step - loss: 0.5608 - accuracy: 0.7232 - val_loss: 0.5076 - val_accuracy: 0.7698
# Epoch 45/60
# 64/64 [==============================] - 11s 169ms/step - loss: 0.5517 - accuracy: 0.7436 - val_loss: 0.7427 - val_accuracy: 0.6230
# Epoch 46/60
# 64/64 [==============================] - 11s 178ms/step - loss: 0.5607 - accuracy: 0.6830 - val_loss: 0.6115 - val_accuracy: 0.6508
# Epoch 47/60
# 64/64 [==============================] - 11s 167ms/step - loss: 0.5728 - accuracy: 0.6917 - val_loss: 0.5453 - val_accuracy: 0.7341
# Epoch 48/60
# 64/64 [==============================] - 11s 167ms/step - loss: 0.5230 - accuracy: 0.7498 - val_loss: 0.5736 - val_accuracy: 0.6865
# Epoch 49/60
# 64/64 [==============================] - 11s 179ms/step - loss: 0.5281 - accuracy: 0.7461 - val_loss: 0.5742 - val_accuracy: 0.6865
# Epoch 50/60
# 64/64 [==============================] - 11s 170ms/step - loss: 0.5483 - accuracy: 0.7267 - val_loss: 0.5526 - val_accuracy: 0.6746
# Epoch 51/60
# 64/64 [==============================] - 11s 168ms/step - loss: 0.5317 - accuracy: 0.7327 - val_loss: 0.5150 - val_accuracy: 0.7817
# Epoch 52/60
# 64/64 [==============================] - 11s 179ms/step - loss: 0.5367 - accuracy: 0.7273 - val_loss: 0.5112 - val_accuracy: 0.7698
# Epoch 53/60
# 64/64 [==============================] - 11s 166ms/step - loss: 0.5425 - accuracy: 0.7010 - val_loss: 0.5120 - val_accuracy: 0.7421
# Epoch 54/60
# 64/64 [==============================] - 11s 168ms/step - loss: 0.5894 - accuracy: 0.6955 - val_loss: 0.5074 - val_accuracy: 0.7738
# Epoch 55/60
# 64/64 [==============================] - 11s 178ms/step - loss: 0.5447 - accuracy: 0.7245 - val_loss: 0.5568 - val_accuracy: 0.7302
# Epoch 56/60
# 64/64 [==============================] - 11s 168ms/step - loss: 0.5629 - accuracy: 0.7162 - val_loss: 0.5373 - val_accuracy: 0.7381
# Epoch 57/60
# 64/64 [==============================] - 11s 168ms/step - loss: 0.5574 - accuracy: 0.7249 - val_loss: 0.5687 - val_accuracy: 0.7143
# Epoch 58/60
# 64/64 [==============================] - 12s 181ms/step - loss: 0.5469 - accuracy: 0.7365 - val_loss: 0.5759 - val_accuracy: 0.6786
# Epoch 59/60
# 64/64 [==============================] - 11s 166ms/step - loss: 0.5506 - accuracy: 0.7089 - val_loss: 0.5043 - val_accuracy: 0.7460
# Epoch 60/60
# 64/64 [==============================] - 11s 167ms/step - loss: 0.5376 - accuracy: 0.7235 - val_loss: 0.5022 - val_accuracy: 0.7738

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)


plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        random_num = np.random.randint(0, len(images))
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[random_num].numpy().astype("uint8"))
        plt.title(class_names[labels[random_num]])
        plt.axis("off")




plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %% [markdown]
# The training and validation accuracy are similar, and the loss function also. This means we do not have overfitting.
# Data augmentation in the form of Randomflip and Randomrotation along with a dropout layer were added to achieve this.
# It was noticed that having an activation function like relu or sigmoid in the dense layer before the final output layer,
# caused convergence problems where the loss function would often get stuck in a local minimum.
